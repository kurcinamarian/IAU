# %% [markdown]
# <center>
# <h1>Intelligent Data Analysis Project</h1>
# <h4>Matej Bebej (50%), Marian Kurcina (50%)</h4>
# </center>

# %% [markdown]
# ## Table of Contents
#
# - [Assignment](#assignment)
# - [Phase 1 - Exploratory Data Analysis](#phase-1---exploratory-data-analysis)
#   - [1.1 - Basic description of data and their characteristics](#11---basic-description-of-data-and-their-characteristics)
#     - [A - Data structure analysis](#a---data-structure-analysis)
#       - [Observation](#observation-1)
#       - [Patient](#patient-1)
#       - [Station](#station-1)
#     - [B - Analysis of individual attributes](#b---analysis-of-individual-attributes)
#     - [C - Pairwise data analysis](#c---pairwise-data-analysis)
#       - [Observation](#observation-2)
#       - [Patient](#patient-2)
#       - [Station](#station-2)
#     - [D - Potential predictors](#d---potential-predictors)
#     - [E - Observations](#observations)
#   - [1.2 - Identification of problems, data integration, and cleaning](#12---identification-of-problems-data-integration-and-cleaning)
#     - [A - Data problems](#data-problems)
#     - [B - Data accuracy check](#data-accuracy-check)
#     - [C - Outlier detection](#outlier-detection)
#   - [1.3 - Formulation and statistical verification of hypotheses about the data](#13---formulation-and-statistical-verification-of-hypotheses-about-the-data)
#     - [Hypothesis 1](#hypothesis-1)
#       - [Statistical power](#statistical-power-1)
#     - [Hypothesis 2](#hypothesis-2)
#       - [Statistical power](#statistical-power-2)
# - [Conclusion](#conclusion)

# %% [markdown]
# <a id="assignment"></a>
# # Assignment

# %% [markdown]
# Oxygen saturation is a key indicator of the proper functioning of the respiratory and circulatory systems. When its value drops to a critically low level, it may indicate life-threatening conditions such as hypoxemia, respiratory failure, or severe infections. In such cases, immediate intervention is essential. Traditional monitoring is performed using pulse oximeters, which, however, can be affected by noise, motion artifacts, or may have limitations in certain clinical situations.
#
# Modern machine learning–based approaches offer the possibility to estimate and predict critical oxygen saturation values with higher accuracy (critical oxygen saturation estimation). Models can utilize multimodal data, such as heart rate, respiratory rate, blood pressure, or sensor signals. By being trained on diverse datasets, it is possible to identify early warning signs of desaturation, filter out noise, and provide timely alerts even before oxygen saturation drops below a safe threshold.
#
# The goal of this assignment is to become familiar with the issue of oxygen saturation monitoring, understand the contribution of artificial intelligence, and design a solution that could improve critical care and reduce risks associated with undiagnosed hypoxemia.
#
# Each pair of students will work with an assigned dataset starting from Week 2. Your task is to predict the dependent variable “oximetry” (the predicted variable) using machine learning methods. In doing so, you will need to deal with various issues present in the data, such as inconsistent formats, missing values, outliers, and others.
#
# The expected outcomes of the project are:
#
#  - the best-performing machine learning model, and
#
#  - a data pipeline for building it from the input data.

# %% [markdown]
# <a id="phase-1---exploratory-data-analysis"></a>
# # Phase 1 – Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import re
from scipy.stats import normaltest, kruskal, iqr, shapiro, mannwhitneyu
import dateparser
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.stats as sm_stats
observation = pd.read_csv("dataset/observation.csv", sep='\t')
patient = pd.read_csv("dataset/patient.csv", sep='\t')
station = pd.read_csv("dataset/station.csv", sep='\t')

# %% [markdown]
# <a id="11---basic-description-of-data-and-their-characteristics"></a>
# ## 1.1 - Basic description of data and their characteristics

# %% [markdown]
# <a id="a---data-structure-analysis"></a>
# ### A - Data structure analysis

# %% [markdown]
# Analyze file structures and relationships (number, types, etc.), records (structure, number of records, number of attributes, types, etc.).
# <br>

# %% [markdown]
# <a id="observation-1"></a>
# #### Observation

# %%
observation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12107 entries, 0 to 12106
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SpO₂                   12107 non-null  float64
#  1   HR                     12107 non-null  float64
#  2   PI                     12107 non-null  float64
#  3   RR                     12107 non-null  float64
#  4   EtCO₂                  12107 non-null  float64
#  5   FiO₂                   12107 non-null  float64
#  6   PRV                    12107 non-null  float64
#  7   BP                     12107 non-null  float64
#  8   Skin Temperature       12107 non-null  float64
#  9   Motion/Activity index  12107 non-null  float64
#  10  PVI                    12107 non-null  float64
#  11  Hb level               12107 non-null  float64
#  12  SV                     12107 non-null  float64
#  13  CO                     12107 non-null  float64
#  14  Blood Flow Index       12107 non-null  float64
#  15  PPG waveform features  12107 non-null  float64
#  16  Signal Quality Index   12107 non-null  float64
#  17  Respiratory effort     12107 non-null  float64
#  18  O₂ extraction ratio    12107 non-null  float64
#  19  SNR                    12107 non-null  float64
#  20  oximetry               12107 non-null  float64
#  21  latitude               12107 non-null  float64
#  22  longitude              12107 non-null  float64
# dtypes: float64(23)
# memory usage: 2.1 MB

# %%
observation.nunique()
# Out:
# SpO₂                     11928
# HR                       11928
# PI                       11928
# RR                       11928
# EtCO₂                    11928
# FiO₂                     11928
# PRV                      11928
# BP                       11928
# Skin Temperature         11928
# Motion/Activity index    11928
# PVI                      11928
# Hb level                 11928
# SV                       11928
# CO                       11928
# Blood Flow Index         11928
# PPG waveform features    11928
# Signal Quality Index     11928
# Respiratory effort       11928
# O₂ extraction ratio      11928
# SNR                      11928
# oximetry                     2
# latitude                   519
# longitude                  519
# dtype: int64

# %% [markdown]
# From following output, we can deduce that the dataset "observation" includes:
# - 12107 entries (rows)
# - 23 atributes (columns)
#
# The dataset contains following attributes for each record:
#
# SpO₂, HR, PI, RR, EtCO₂, FiO₂, PRV, BP, Skin Temperature, Motion/Activity index, PVI, Hb level, SV, CO, Blood Flow Index,PPG waveform features, Signal Quality Index, Respiratory effort, O₂ extraction ratio, SNR, oximetry, latitude, longitude
#
# There are no attributes with null values, all attributes are float type.
#
# <br>

# %% [markdown]
# <a id="patient-1"></a>
# #### Patient

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128 entries, 0 to 2127
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   residence         0 non-null      float64
#  1   current_location  2022 non-null   object
#  2   blood_group       2128 non-null   object
#  3   job               638 non-null    object
#  4   mail              2128 non-null   object
#  5   user_id           2128 non-null   int64
#  6   birthdate         1170 non-null   object
#  7   company           2128 non-null   object
#  8   name              2128 non-null   object
#  9   username          2128 non-null   object
#  10  ssn               2128 non-null   object
#  11  registration      2128 non-null   object
#  12  station_ID        2128 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.3+ KB

# %%
patient.isnull().sum()
# Out:
# residence           2128
# current_location     106
# blood_group            0
# job                 1490
# mail                   0
# user_id                0
# birthdate            958
# company                0
# name                   0
# username               0
# ssn                    0
# registration           0
# station_ID             0
# dtype: int64

# %%
patient.nunique()
# Out:
# residence              0
# current_location    2022
# blood_group            8
# job                  402
# mail                2121
# user_id             1379
# birthdate           1150
# company             1934
# name                2073
# username            2100
# ssn                 2128
# registration        1918
# station_ID           719
# dtype: int64

# %% [markdown]
# From following output, we can deduce that the dataset "patient" includes:
# - 2128 entries (rows)
# - 13 atributes (columns)
#
# The dataset contains following attributes for records:
#
# residence, current_location, blood_group, job, mail, user_id, birthdate, company, name, username, ssn, registration, station_ID
#
# There are several attributes with null values:
# - residence - this attribute is not needed since it contains no non-null values
# - current_location - this attribute has 106 null values
# - job - this attribute has 1490 null values
# - birthday - this attribute has 958 null values
#
# residence is float type.
# current_location, blood_group, job, mail, birthdate, company, name, username, ssn, registration are object type.
# user_id, station_ID are int type
#
# <br>

# %% [markdown]
# <a id="station-1"></a>
# #### Station

# %%
station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   772 non-null    object
#  1   code       770 non-null    object
#  2   revision   772 non-null    object
#  3   station    772 non-null    object
#  4   latitude   772 non-null    float64
#  5   longitude  772 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 36.3+ KB

# %%
station.isnull().sum()
# Out:
# location     0
# code         2
# revision     0
# station      0
# latitude     0
# longitude    0
# dtype: int64

# %%
station.nunique()
# Out:
# location     135
# code          94
# revision     760
# station      519
# latitude     519
# longitude    519
# dtype: int64

# %% [markdown]
# From following output, we can deduce that the dataset "station" includes:
# - 772 entries (rows)
# - 6 atributes (columns)
#
# The dataset contains following attributes for records:
#
# location, code, revision, station, latitude, longtitude
#
# There is only one attribute which cntains null values:
# - code - this attribute has 2 null values
#
# location, code, revision, station is object type.
# latitude, longtitude are float type.
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="b---analysis-of-individual-attributes"></a>
# ### B - Analysis of individual attributes

# %% [markdown]
# For at least 10 selected significant attributes, analyze their distributions and basic descriptive statistics, and check whether they meet the required conditions and the expected range of measured values.
#
# <br>

# %%
observation.describe()
# Out:
#                SpO₂            HR            PI            RR         EtCO₂  \
# count  12107.000000  12107.000000  12107.000000  12107.000000  12107.000000
# mean      97.720877     78.139220      9.280387     16.420159     39.761272
# std        0.849157      4.782149      3.432338      1.287131      1.220140
# min       95.000000     60.000000      0.200000     12.000000     35.000000
# 25%       97.073862     74.938806      6.543803     15.418921     38.840854
# 50%       97.850262     78.124134      8.703433     16.493047     39.782823
# 75%       98.359154     81.345487     12.159623     17.466124     40.708415
# max      100.000000    100.000000     20.000000     20.000000     45.000000
#
#                FiO₂           PRV            BP  Skin Temperature  \
# count  12107.000000  12107.000000  12107.000000      12107.000000
# mean      61.836198    106.629738    106.142109         35.712456
# std       10.182272     24.520873      3.676340          0.606630
# min       21.000000     20.000000     90.000000         33.000000
# 25%       55.076625     90.088136    103.704873         35.307574
# 50%       61.853122    106.339196    106.122106         35.711898
# 75%       68.679155    123.256573    108.536922         36.114306
# max      100.000000    200.000000    120.000000         38.000000
#
#        Motion/Activity index  ...            CO  Blood Flow Index  \
# count           12107.000000  ...  12107.000000      12107.000000
# mean               10.013732  ...      4.068934         51.897652
# std                 1.009803  ...      0.094006         12.439194
# min                 6.063736  ...      4.000000          0.000000
# 25%                 9.331576  ...      4.021535         43.468302
# 50%                10.012485  ...      4.041752         51.983722
# 75%                10.698413  ...      4.081694         60.322630
# max                14.205771  ...      8.000000        100.000000
#
#        PPG waveform features  Signal Quality Index  Respiratory effort  \
# count           12107.000000          12107.000000        12107.000000
# mean               51.293918             50.545308           55.540997
# std                11.859092             12.741621           11.301895
# min                 0.000000              0.000000            0.000000
# 25%                43.298068             42.100520           47.965348
# 50%                51.298702             50.436869           55.588062
# 75%                59.309318             59.247765           63.116464
# max               100.000000            100.000000          100.000000
#
#        O₂ extraction ratio           SNR      oximetry      latitude  \
# count         12107.000000  12107.000000  12107.000000  12107.000000
# mean              0.249564     29.975732      0.596845     28.671404
# std               0.028901      5.765204      0.490552     23.945771
# min               0.200000     20.000000      0.000000    -54.800000
# 25%               0.224556     24.960719      0.000000     14.420440
# 50%               0.249187     30.054808      1.000000     36.246240
# 75%               0.274669     34.948440      1.000000     46.518720
# max               0.300000     40.000000      1.000000     65.933810
#
#           longitude
# count  12107.000000
# mean       9.237063
# std       73.361001
# min     -156.474320
# 25%      -67.331220
# 50%        8.881040
# 75%       71.211690
# max      168.313660
#
# [8 rows x 23 columns]

# %% [markdown]
# |Attribute Name|Description|Mean (Average)|Standard Deviation| Minimum| Maximum| Q1|Q2|Q3|Acceptable Range|
# |--------------|-----------|--------------|------------------|--------|--------|---|--|--|----------------|
# |SpO₂|Peripheral oxygen saturation|97.720877|0.849157|95|100|97.073862|97.850262|98.359154|95-100%|
# |HR|Heart rate from pulse oximeter|78.139220|4.782149|60|100|74.938806|78.124134|81.345487|60-100bpm|
# |PI|Perfusion index|9.280387|3.432338|0.2|20|6.543803|8.703433|12.159623|0.2-20%|
# |RR|Respiratory rate|16.420159|1.287131|12|20|15.418921|16.493047|17.466124|12-20 breaths/min|
# |EtCO₂|End-tidal carbon dioxide|39.761272|1.220140|35|45|38.840854|39.782823|40.708415|35-45 mmHG|
# |FiO₂|Fraction of inspired oxygen|61.836198|10.182272|21|100|55.076625|61.853122|68.679155|21-100%|
# |PRV|Pulse rate variability|106.629738|24.520873|20|200|90.088136|106.339196|123.256573|20-200ms|
# |BP|Blood pressure (systolic diastolic mean)|106.142109|3.676340|90|120|103.704873|106.122106|108.536922|90/60-120/80 mmHg
# |Skin Temperature|Peripheral temperature|35.712456|0.606630|33|38|35.307574|35.711898|36.114306|33-38°C|
# |Motion/Activity index|Sensor artifact correction|10.013732|1.009803|6.063736|14.205771|9.331576|10.012485|10.698413||
# |PVI|Pleth Variability Index|14.946319|1.322060|10|20|14.085887|14.940500|15.813169|10-20%|
# |Hb level|Hemoglobin concentration|14.919731|0.818275|12|18|14.369708|14.921914|15.468757|12-18 g/dL|
# |SV|Stroke volume|87.122299|3.480042|60|100|84.775740|87.120146|89.443815|60-100 mL/beat|
# |CO|Cardiac output|4.068934|0.094006|4|8|4.021535|4.041752|4.081694|4-8 L/min|
# |Blood Flow Index|Optical/near-infrared blood flow measurement|51.897652|12.439194|0|100|43.468302|51.983722|60.322630||
# |PPG waveform features|Photoplethysmography signal parameters|51.293918|11.859092|0|100|43.298068|51.298702|59.309318||
# |Signal Quality Index|Reliability indicator of readings|50.545308|12.741621|0|100|42.100520|50.436869|59.247765|0-100%|
# |Respiratory effort|Chest impedance or belt-derived effort|55.540997|11.301895|0|100|47.965348|55.588062|63.116464||
# |O₂ extraction ratio|Calculated oxygen extraction metric|0.249564|0.028901|0.2|0.3|0.224556|0.249187|0.274669|0.2-0.3
# |SNR|Signal-to-noise ratio from sensor|29.975732|5.765204|20|40|24.960719|30.054808|34.948440|20-40 dB|
# |latitude||28.671404|23.945771|-54.8|65.933810|14.420440|36.246240|46.518720|-90°-90°|
# |longitude||9.237063|73.361001|-156.474320|168.313660|-67.331220|8.881040|71.211690|-180°-180°|
#
# We can see that all attributes are in accetable range, therefore we can expect that no attributes are inputed incorrectly.
# Attribute Oximetry is float type, however it contains only values 0 and 1, therefore we can say it is boolean attribute.
#
# <br>

# %%
observation.hist(figsize=(18, 18), bins=20)
plt.suptitle("Distributions of attributes")
plt.show()

# %%
for col in observation.select_dtypes(include='number').columns:
    data = observation[col].dropna()
    stat, p = normaltest(data)
    print(f"{col}: {p} -> {'normal' if p > 0.05 else 'not normal'},\n {data.skew()} skew,\n {data.kurt()} kurtosis\n")
# Out:
# SpO₂: 1.5363139954530892e-158 -> not normal,
#  -0.3371814826310864 skew,
#  -0.6530604770313353 kurtosis
#
# HR: 0.9553892210919934 -> normal,
#  0.003649593813801721 skew,
#  -0.012198051820739408 kurtosis
#
# PI: 0.0 -> not normal,
#  0.27027624269939854 skew,
#  -0.8719145282774083 kurtosis
#
# RR: 1.6083536221895697e-137 -> not normal,
#  -0.24267009668789452 skew,
#  -0.6551747223669224 kurtosis
#
# EtCO₂: 1.1616870273859805e-64 -> not normal,
#  -0.0351635784741534 skew,
#  -0.5429531773823051 kurtosis
#
# FiO₂: 0.6906212807747991 -> normal,
#  -0.01904136033613549 skew,
#  0.003026216294312878 kurtosis
#
# PRV: 0.207089424253633 -> normal,
#  0.009553974743601194 skew,
#  -0.07466967971266136 kurtosis
#
# BP: 1.2644694089796055e-05 -> not normal,
#  -0.01514828709809658 skew,
#  0.23172030878590055 kurtosis
#
# Skin Temperature: 0.39950799138486687 -> normal,
#  0.008046092454978062 skew,
#  0.0587472318867559 kurtosis
#
# Motion/Activity index: 0.6652781837578627 -> normal,
#  0.016548964099385464 skew,
#  -0.023477062743010535 kurtosis
#
# PVI: 0.00016719228556419364 -> not normal,
#  0.019509065754772233 skew,
#  0.19791296103654377 kurtosis
#
# Hb level: 0.982628962913725 -> normal,
#  -0.003967384427420091 skew,
#  0.0015516587829953465 kurtosis
#
# SV: 3.287241088738921e-11 -> not normal,
#  -0.05110118308491601 skew,
#  0.33861363489072094 kurtosis
#
# CO: 0.0 -> not normal,
#  9.933973469087164 skew,
#  287.0068855243398 kurtosis
#
# Blood Flow Index: 0.6070110820641146 -> normal,
#  -0.02108818798999002 skew,
#  -0.014967100696665625 kurtosis
#
# PPG waveform features: 0.9994231801910105 -> normal,
#  0.00010638903230415165 skew,
#  -0.0024803123424579354 kurtosis
#
# Signal Quality Index: 0.7253832646785978 -> normal,
#  0.012951331626451144 skew,
#  0.02378967973137236 kurtosis
#
# Respiratory effort: 0.37490804875733896 -> normal,
#  -0.021744790212889314 skew,
#  0.044624949533147884 kurtosis
#
# O₂ extraction ratio: 0.0 -> not normal,
#  0.0191936256660769 skew,
#  -1.1985996920902784 kurtosis
#
# SNR: 0.0 -> not normal,
#  -0.006090321561181403 skew,
#  -1.197080995287174 kurtosis
#
# oximetry: 0.0 -> not normal,
#  -0.39490558589213703 skew,
#  -1.8443542812152005 kurtosis
#
# latitude: 0.0 -> not normal,
#  -1.1087115829886809 skew,
#  0.5707600269474224 kurtosis
#
# longitude: 0.0 -> not normal,
#  -0.00196885781215154 skew,
#  -0.9247337154029065 kurtosis

# %% [markdown]
# We can see that attributes with normal distribution are:
# - HR
# - FiO₂
# - PRV
# - Skin Temperature
# - Motion/Activity index
# - Hb level
# - Blood Flow Index
# - PPG waveform features
# - Signal Quality Index
# - Respiratory effort
#
# <br>

# %%
numeric_cols = observation.select_dtypes(include=["float64", "int64"]) #vpodstate vse
rows, cols = 5, 5
fig, axes = plt.subplots(rows, cols, figsize=(20, 20))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    numeric_cols.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col, fontsize=12)
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.suptitle("Boxplots of Attributes", fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# There are some outliers for attributes, but since they are in valid range, we will keep them and not alter them (delete them).
#
# ---
#
# <br><br><br>

# %% [markdown]
# <br><br>

# %% [markdown]
# <a id="c---pairwise-data-analysis"></a>
# ### C - Pairwise data analysis

# %% [markdown]
# Identify relationships and dependencies between pairs of attributes.
#
# <br><br>

# %% [markdown]
# <a id="observation-2"></a>
# #### Observation

# %%
corr = observation.corr(numeric_only=True)

plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# The resulting heatmap highlights which attributes are most related to each other and to the target variable which is oximetry. We can safely assume which variables may be redundant or highly correlated.

# %%
# Create 4x4 grid for 13 plots (we'll have 3 empty spots)
fig, axes = plt.subplots(4, 4, figsize=(20, 16))

# All pairs with |correlation| >= 0.10:

# 1. SpO2 vs PI: -0.52
sns.scatterplot(x='SpO₂', y='PI', data=observation, ax=axes[0,0])
axes[0,0].set_title('SpO2 vs PI (corr: -0.52)')

# 2. SpO2 vs RR: 0.37
sns.scatterplot(x='SpO₂', y='RR', data=observation, ax=axes[0,1])
axes[0,1].set_title('SpO2 vs RR (corr: 0.37)')

# 3. SpO2 vs oximetry: 0.36
sns.scatterplot(x='SpO₂', y='oximetry', data=observation, ax=axes[0,2])
axes[0,2].set_title('SpO2 vs oximetry (corr: 0.36)')

# 4. PI vs EtCO2: 0.37
sns.scatterplot(x='PI', y='EtCO₂', data=observation, ax=axes[0,3])
axes[0,3].set_title('PI vs EtCO2 (corr: 0.37)')

# 5. RR vs EtCO2: 0.27
sns.scatterplot(x='RR', y='EtCO₂', data=observation, ax=axes[1,0])
axes[1,0].set_title('RR vs EtCO2 (corr: 0.27)')

# 6. RR vs oximetry: 0.66
sns.scatterplot(x='RR', y='oximetry', data=observation, ax=axes[1,1])
axes[1,1].set_title('RR vs oximetry (corr: 0.66)')

# 7. PI vs oximetry: -0.52
sns.scatterplot(x='PI', y='oximetry', data=observation, ax=axes[1,2])
axes[1,2].set_title('PI vs oximetry (corr: -0.52)')

# 8. EtCO2 vs oximetry: 0.29
sns.scatterplot(x='EtCO₂', y='oximetry', data=observation, ax=axes[1,3])
axes[1,3].set_title('EtCO2 vs oximetry (corr: 0.29)')

# 9. HR vs CO: 0.74
sns.scatterplot(x='HR', y='CO', data=observation, ax=axes[2,0])
axes[2,0].set_title('HR vs CO (corr: 0.74)')

# 10. PI vs BP: 0.13
sns.scatterplot(x='PI', y='BP', data=observation, ax=axes[2,1])
axes[2,1].set_title('PI vs BP (corr: 0.13)')

# 11. RR vs PVI: 0.15
sns.scatterplot(x='RR', y='PVI', data=observation, ax=axes[2,2])
axes[2,2].set_title('RR vs PVI (corr: 0.15)')

# 12. PVI vs oximetry: 0.11
sns.scatterplot(x='PVI', y='oximetry', data=observation, ax=axes[2,3])
axes[2,3].set_title('PVI vs oximetry (corr: 0.11)')

# 13. SpO2 vs EtCO2: -0.15
sns.scatterplot(x='SpO₂', y='EtCO₂', data=observation, ax=axes[3,0])
axes[3,0].set_title('SpO2 vs EtCO2 (corr: -0.15)')

# Hide the 3 empty subplots
axes[3,1].set_visible(False)
axes[3,2].set_visible(False)
axes[3,3].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# The resulting visualization makes it easy to see which variables are most strongly related:
#
# The strongest positive correlation is between HR (heart rate) and CO (cardiac output, r = 0.74).
#
# RR (respiratory rate) and oximetry also show a notable positive correlation (r = 0.66).
#
# Negative correlations are observed between PI (perfusion index) and both SpO₂ (r = –0.52) and oximetry (r = –0.52).
#
# Thanks to the plots, we can visually confirm and support the correlation results. The results are showing are both the strength and pattern of dependencies between key physiological parameters and the predicted variable -> oximetry.
# <br><br>

# %% [markdown]
# <a id="patient-2"></a>
# #### Patient

# %%
patient.head()
# Out:
#    residence                                current_location blood_group  job  \
# 0        NaN  (Decimal('-39.6140315'), Decimal('22.351713'))          A+  NaN
# 1        NaN    (Decimal('69.634637'), Decimal('66.117558'))         AB-  NaN
# 2        NaN   (Decimal('19.563271'), Decimal('-41.108627'))         AB-  NaN
# 3        NaN   (Decimal('34.010482'), Decimal('129.946434'))          O-  NaN
# 4        NaN   (Decimal('61.148803'), Decimal('115.371931'))          O+  NaN
#
#                           mail  user_id   birthdate               company  \
# 0          schachtkaren@web.de     1135  1923-01-03      Ruppert Stey GbR
# 1             plopes@gmail.com      773  1918-05-23    Gonçalves e Filhos
# 2       tanakayoko@hotmail.com     1532  2001-01-04              中村食品有限会社
# 3        brandoncruz@yahoo.com     2025         NaN         Silva-Gardner
# 4  serragliogiorgio@tiscali.it      638  1997-05-14  Ortese-Agnesi s.r.l.
#
#                      name          username               ssn  \
# 0         Raymund Benthin         hornigdan       226-93-4078
# 1       Leonardo Mendonça     diasana-clara       35096471810
# 2                   吉田 陽子          sayuri90       066-73-4209
# 3            Scott Thomas           rossjoy       368-27-2375
# 4  Dott. Maurilio Zanazzo  orlandogilardoni  SNSGNT39E71B896C
#
#            registration  station_ID
# 0            2021-04-21         729
# 1  12/16/2019, 00:00:00         668
# 2            2023/01/30         482
# 3           09 Feb 2024         284
# 4            2022-03-09         572

# %% [markdown]
# We can see that current_location contains latitude and longitude, therefore we have decided to split them into 2 columns. Also there are different date formats which we need to make into same format.

# %%
coords = patient['current_location'].str.extract(
    r"Decimal\('([-0-9.]+)'\).*Decimal\('([-0-9.]+)'\)"
)

patient['latitude'] = pd.to_numeric(coords[0], errors='coerce')
patient['longitude'] = pd.to_numeric(coords[1], errors='coerce')

patient.describe()
# Out:
#        residence      user_id   station_ID     latitude    longitude
# count        0.0  2128.000000  2128.000000  2022.000000  2022.000000
# mean         NaN  1074.037594   390.836936     0.449233     3.536263
# std          NaN   611.516264   224.274660    52.214570   102.595709
# min          NaN     0.000000     0.000000   -89.974802  -179.928645
# 25%          NaN   554.000000   193.000000   -45.312505   -85.899696
# 50%          NaN  1074.500000   394.000000     0.405269     8.928997
# 75%          NaN  1607.250000   587.250000    46.580815    92.708868
# max          NaN  2127.000000   770.000000    89.835507   179.913557

# %% [markdown]
# Here we have split the attribute "current_location" which before contained both latitude and longtitude to the seperate attributes. With this we hope that we will be able to connect several tables.

# %% [markdown]
# <a id="station-2"></a>
# #### Station

# %%
station.head()
# Out:
#           location code              revision                   station  \
# 0    Europe/Madrid   ES  12/22/2016, 00:00:00  San Juan de Aznalfarache
# 1   America/Bogota   CO           22 Jul 2023         Villa del Rosario
# 2     Asia/Kolkata   IN            2022/09/04                    Rangia
# 3  America/Chicago   US            2021/03/29                     Rolla
# 4    Europe/Berlin   DE            2023/09/12                  Albstadt
#
#    latitude  longitude
# 0  37.35813   -6.03731
# 1   7.83389  -72.47417
# 2  26.44931   91.61356
# 3  37.95143  -91.77127
# 4  48.21644    9.02596

# %%
station.describe()
# Out:
#          latitude   longitude
# count  772.000000  772.000000
# mean    28.652487    9.132671
# std     23.967608   73.458813
# min    -54.800000 -156.474320
# 25%     14.443685  -67.331220
# 50%     36.230840    8.874040
# 75%     46.372028   69.920535
# max     65.933810  168.313660

# %%
observation.describe()
# Out:
#                SpO₂            HR            PI            RR         EtCO₂  \
# count  12107.000000  12107.000000  12107.000000  12107.000000  12107.000000
# mean      97.720877     78.139220      9.280387     16.420159     39.761272
# std        0.849157      4.782149      3.432338      1.287131      1.220140
# min       95.000000     60.000000      0.200000     12.000000     35.000000
# 25%       97.073862     74.938806      6.543803     15.418921     38.840854
# 50%       97.850262     78.124134      8.703433     16.493047     39.782823
# 75%       98.359154     81.345487     12.159623     17.466124     40.708415
# max      100.000000    100.000000     20.000000     20.000000     45.000000
#
#                FiO₂           PRV            BP  Skin Temperature  \
# count  12107.000000  12107.000000  12107.000000      12107.000000
# mean      61.836198    106.629738    106.142109         35.712456
# std       10.182272     24.520873      3.676340          0.606630
# min       21.000000     20.000000     90.000000         33.000000
# 25%       55.076625     90.088136    103.704873         35.307574
# 50%       61.853122    106.339196    106.122106         35.711898
# 75%       68.679155    123.256573    108.536922         36.114306
# max      100.000000    200.000000    120.000000         38.000000
#
#        Motion/Activity index  ...            CO  Blood Flow Index  \
# count           12107.000000  ...  12107.000000      12107.000000
# mean               10.013732  ...      4.068934         51.897652
# std                 1.009803  ...      0.094006         12.439194
# min                 6.063736  ...      4.000000          0.000000
# 25%                 9.331576  ...      4.021535         43.468302
# 50%                10.012485  ...      4.041752         51.983722
# 75%                10.698413  ...      4.081694         60.322630
# max                14.205771  ...      8.000000        100.000000
#
#        PPG waveform features  Signal Quality Index  Respiratory effort  \
# count           12107.000000          12107.000000        12107.000000
# mean               51.293918             50.545308           55.540997
# std                11.859092             12.741621           11.301895
# min                 0.000000              0.000000            0.000000
# 25%                43.298068             42.100520           47.965348
# 50%                51.298702             50.436869           55.588062
# 75%                59.309318             59.247765           63.116464
# max               100.000000            100.000000          100.000000
#
#        O₂ extraction ratio           SNR      oximetry      latitude  \
# count         12107.000000  12107.000000  12107.000000  12107.000000
# mean              0.249564     29.975732      0.596845     28.671404
# std               0.028901      5.765204      0.490552     23.945771
# min               0.200000     20.000000      0.000000    -54.800000
# 25%               0.224556     24.960719      0.000000     14.420440
# 50%               0.249187     30.054808      1.000000     36.246240
# 75%               0.274669     34.948440      1.000000     46.518720
# max               0.300000     40.000000      1.000000     65.933810
#
#           longitude
# count  12107.000000
# mean       9.237063
# std       73.361001
# min     -156.474320
# 25%      -67.331220
# 50%        8.881040
# 75%       71.211690
# max      168.313660
#
# [8 rows x 23 columns]

# %% [markdown]
# We have noticed, that there are different date formats which we will need to make into same format. Furthermore we have noticed that sation.latitude and station.longitude have same distributions, std and mean as observation.latitude and observation.longitude, we can expect that these connect the two datasets.

# %%
station_coords = set(zip(station['latitude'], station['longitude']))

observation['matches_station'] = observation.apply(
    lambda row: (row['latitude'], row['longitude']) in station_coords, axis=1
)

num_matches = observation['matches_station'].sum()
total_obs = len(observation)

print(f"{num_matches} out of {total_obs} observations match station coordinates.")
observation.drop(columns=['matches_station'], inplace=True)
# Out:
# 12107 out of 12107 observations match station coordinates.

# %%
observation_coords = set(zip(observation['latitude'], observation['longitude']))

station['has_observation'] = station.apply(
    lambda row: (row['latitude'], row['longitude']) in observation_coords, axis=1
)

num_matches = station['has_observation'].sum()
total_stations = len(station)

print(f"{num_matches} out of {total_stations} stations have matching observation coordinates.")
station.drop(columns=['has_observation'], inplace=True)
# Out:
# 772 out of 772 stations have matching observation coordinates.

# %% [markdown]
# It was confirmed that station cordinates match with observation cordinates and vice versa.
#
# With this information we can safely merge them (e.g., by latitude and longitude or station ID) without worrying about mismatched entries.
#
# It also indicates data quality is high — no missing or corrupted coordinate pairs (logtitutde and latitude).
#
# Every observation can be reliably linked to a station-level context (e.g., device location, altitude, or environmental conditions).
#
# Result: Datasets are alligned - every observation belongs to a known station, and every station has at least one observation.
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="d---potential-predictors"></a>
# ### D - Potential predictors

# %% [markdown]
# Identify dependencies between the predicted variable and other variables (potential predictors).

# %%
numeric_cols = observation.select_dtypes(include=np.number).columns

corr_spearman = observation[numeric_cols].corr(method='spearman')['oximetry'].sort_values(ascending=False)

print(corr_spearman)
# Out:
# oximetry                 1.000000
# RR                       0.669143
# SpO₂                     0.400411
# EtCO₂                    0.307589
# BP                       0.018955
# Blood Flow Index         0.011153
# HR                       0.010209
# CO                       0.010190
# Respiratory effort       0.006981
# Signal Quality Index     0.006935
# longitude                0.006118
# Motion/Activity index    0.006110
# Hb level                -0.001174
# SNR                     -0.003230
# PRV                     -0.003779
# PPG waveform features   -0.004232
# FiO₂                    -0.004978
# Skin Temperature        -0.006122
# latitude                -0.007828
# O₂ extraction ratio     -0.010159
# SV                      -0.019628
# PVI                     -0.105327
# PI                      -0.119275
# Name: oximetry, dtype: float64

# %% [markdown]
# Based on Spearman’s correlation, the attributes with the strongest relationship to the target variable oximetry were identified.
# The variable “RR” (respiratory rate) shows the highest positive correlation, followed by “SpO₂” and “EtCO₂”, suggesting that higher values of these variables tend to be associated with higher oximetry readings.
# Most other variables show very weak or negligible correlations, indicating limited influence on oximetry.
# A few attributes, such as “PVI” and “PI”, exhibit negative correlations, meaning that as these values increase, oximetry tends to decrease slightly.
# The correlations were visualized in the graph below, which illustrates the relative strength and direction of each attribute’s relationship with oximetry.

# %%
corr_filtered = corr_spearman[abs(corr_spearman) > 0.1]
plt.figure(figsize=(8, 6))
sns.barplot(
    x=corr_filtered.values,
    y=corr_filtered.index,
    hue=corr_filtered.index,
    palette='coolwarm',
    orient='h',
    legend=False
)
plt.title('Spearman correlation of each variable with Oximetry', fontsize=14)
plt.xlabel('Correlation coefficient')
plt.ylabel('Attribute')
plt.axvline(0, color='gray', linewidth=0.8)
plt.tight_layout()
plt.show()

# %%
#create grid dimensions
n_plots = len(corr_filtered) - 1 #(-1 bcs we do not need the first attribute)
n_cols = 3
n_rows = (n_plots + n_cols - 1) // n_cols

#here we create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))

#we neeed to faltten the axis
if n_rows > 1:
    axes = axes.flatten()
else:
    axes = [axes] if n_cols == 1 else axes

# Create regplot for each attribute in corr_filtered (we skip the first bcs oximentry vs oximetry is useless)
for i, attribute in enumerate(corr_filtered.index[1:], 0):  # Start from index 1, enumerate from 0
    sns.regplot(x=attribute, y='oximetry', data=observation, ax=axes[i])
    axes[i].set_title(f'{attribute} vs Oximetry\n(corr: {corr_filtered[attribute]:.3f})')

#remove last empty plot
for i in range(n_plots, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# Each subplot displays a scatter plot with a fitted regression line, allowing visual inspection of the direction (we can see both, positive or negative) and strength of the relationships.
# Overall, this visualization helps confirm the correlations numerically identified earlier and provides insight into whether the relationships appear linear or more complex.
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="observations"></a>
# ### E - Observations)

# %% [markdown]
# Observations made by us, which we determined based on us studying this topic nad datasets

# %% [markdown]
# In the following section, we explored the contents of the datasets provided for this project (station, patient, and observation). We examined their structure, data types, and the presence of missing values, as well as the overall correlations and relationships both between the tables and within their individual attributes.
# Our main objective was to focus on the oximetry parameter and to analyze how other attributes correlate with it — whether positively, negatively, or neutrally. The results were visualized using various graphs and plots, each accompanied by a brief interpretation.
# All important observations, findings, and interpretations have been documented directly under the corresponding diagrams and code sections throughout the report.
#
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="12---identification-of-problems-data-integration-and-cleaning"></a>
# ## 1.2 - Identification of problems, data integration, and cleaning

# %% [markdown]
# <a id="data-problems"></a>
# ## A - Data problems

# %% [markdown]
# Identify and initially address data problems such as: unsuitable data structure, duplicate records that may arise after certain transformations, inconsistent formats, missing values, and outliers. Other (not listed) problems may also occur, or fewer problems than those mentioned.

# %% [markdown]
# <a id="observation-3"></a>
# ### Observation

# %% [markdown]
# First we will look if there are any duplicate records.

# %%
observation[observation.duplicated(keep=False)]
# Out:
#            SpO₂         HR        PI         RR      EtCO₂       FiO₂  \
# 2045  97.959363  72.504624  5.982921  17.487597  37.843251  55.169099
# 5160  97.959363  72.504624  5.982921  17.487597  37.843251  55.169099
#
#              PRV          BP  Skin Temperature  Motion/Activity index  ...  \
# 2045  145.133297  104.643107          36.55279              10.057312  ...
# 5160  145.133297  104.643107          36.55279              10.057312  ...
#
#             CO  Blood Flow Index  PPG waveform features  Signal Quality Index  \
# 2045  4.012683         53.145045              62.450684             43.958664
# 5160  4.012683         53.145045              62.450684             43.958664
#
#       Respiratory effort  O₂ extraction ratio        SNR  oximetry  latitude  \
# 2045           46.461306             0.277102  34.929818       1.0  22.19303
# 5160           46.461306             0.277102  34.929818       1.0  22.19303
#
#       longitude
# 2045   88.18466
# 5160   88.18466
#
# [2 rows x 23 columns]

# %% [markdown]
# For observation table there are these problems with data we have noticed:
# - oximetry has more suitable data structure, we will change it from float to boolean
# - we have one duplicate record which we will remove
#
# In observation table there are no null-value records (found in 1.1.A.Observation), that we would have to take care of. All the other attributes are in their valid range (Found in 1.1.B.Observation).

# %%
observation['oximetry'] = observation['oximetry'].astype(bool)
observation.head()
# Out:
#         SpO₂         HR         PI         RR      EtCO₂       FiO₂  \
# 0  96.511604  67.597663  14.451123  17.461063  41.262037  87.821291
# 1  98.113516  72.872900   4.699563  17.231104  40.220086  64.283914
# 2  98.623248  81.418306  12.056504  16.832868  39.953184  77.164206
# 3  96.821905  69.356881  11.044410  14.876013  38.765113  59.296747
# 4  98.523262  70.686313   5.963887  16.933547  41.470854  66.145767
#
#           PRV          BP  Skin Temperature  Motion/Activity index  ...  \
# 0  126.965235  109.471152         35.650826              11.429092  ...
# 1  139.509502  100.943658         35.313317              11.188645  ...
# 2  104.396821  107.401302         36.017931               8.980842  ...
# 3  180.845101  106.786082         35.433515               9.952747  ...
# 4  111.525074  108.354216         35.258355              10.619401  ...
#
#          CO  Blood Flow Index  PPG waveform features  Signal Quality Index  \
# 0  4.004591         44.065731              36.604550             69.140438
# 1  4.014983         36.498878              61.305805             50.733704
# 2  4.083922         52.803185              49.432273             41.841466
# 3  4.006763         52.800923              68.710875             47.524447
# 4  4.008813         25.406073              33.993656             60.323832
#
#    Respiratory effort  O₂ extraction ratio        SNR  oximetry  latitude  \
# 0           57.097309             0.210117  33.584512      True  19.64745
# 1           61.220158             0.293664  30.528645      True  28.15112
# 2           57.554854             0.232518  22.357337      True -38.16604
# 3           48.971775             0.288125  25.886190     False  40.63316
# 4           54.807359             0.295855  20.836752      True   4.88441
#
#    longitude
# 0 -102.04897
# 1  -82.46148
# 2  145.13643
# 3  -74.13653
# 4  101.96857
#
# [5 rows x 23 columns]

# %% [markdown]
# After the changes to the data, we can see now in oximetry table True/false.

# %%
observation = observation.drop_duplicates()
observation[observation.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [SpO₂, HR, PI, RR, EtCO₂, FiO₂, PRV, BP, Skin Temperature, Motion/Activity index, PVI, Hb level, SV, CO, Blood Flow Index, PPG waveform features, Signal Quality Index, Respiratory effort, O₂ extraction ratio, SNR, oximetry, latitude, longitude]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# We have removed the duplicate, when we run the command for searching duplicates we can see that there are none.

# %% [markdown]
# <a id="patient-3"></a>
# ### Patient

# %%
patient = patient.drop_duplicates()
patient[patient.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [residence, current_location, blood_group, job, mail, user_id, birthdate, company, name, username, ssn, registration, station_ID, latitude, longitude]
# Index: []

# %% [markdown]
# For patient table we have these problems:
# - residence table has no non-null values - it should be removed (found in 1.1.A.Patient)
# - current_location, job and birthdate have missing values (found in 1.1.A.Patient) - we wont fix this because this we can declare as optional information for patients
# - birthdate and registration have different date types (found in 1.1.A.Patient) - it should be standarized
# -  there are duplicate mails and usernames (found in 1.1.A.Patient) which should be unique but this can be result of sourcing from different sources - we wont fix this
# -  there are duplicate user_ids (found in 1.1.A.Patient) which should be unique, we will reset the ids
# -  current_location should be partitioned into latitude and longitude ( already done in 1.1.C.Patient) we will also remove the original column
#
# We can see that there are no duplicates.

# %%
patient = patient.drop(columns=['residence'])
patient.head()
# Out:
#                                  current_location blood_group  job  \
# 0  (Decimal('-39.6140315'), Decimal('22.351713'))          A+  NaN
# 1    (Decimal('69.634637'), Decimal('66.117558'))         AB-  NaN
# 2   (Decimal('19.563271'), Decimal('-41.108627'))         AB-  NaN
# 3   (Decimal('34.010482'), Decimal('129.946434'))          O-  NaN
# 4   (Decimal('61.148803'), Decimal('115.371931'))          O+  NaN
#
#                           mail  user_id   birthdate               company  \
# 0          schachtkaren@web.de     1135  1923-01-03      Ruppert Stey GbR
# 1             plopes@gmail.com      773  1918-05-23    Gonçalves e Filhos
# 2       tanakayoko@hotmail.com     1532  2001-01-04              中村食品有限会社
# 3        brandoncruz@yahoo.com     2025         NaN         Silva-Gardner
# 4  serragliogiorgio@tiscali.it      638  1997-05-14  Ortese-Agnesi s.r.l.
#
#                      name          username               ssn  \
# 0         Raymund Benthin         hornigdan       226-93-4078
# 1       Leonardo Mendonça     diasana-clara       35096471810
# 2                   吉田 陽子          sayuri90       066-73-4209
# 3            Scott Thomas           rossjoy       368-27-2375
# 4  Dott. Maurilio Zanazzo  orlandogilardoni  SNSGNT39E71B896C
#
#            registration  station_ID   latitude   longitude
# 0            2021-04-21         729 -39.614032   22.351713
# 1  12/16/2019, 00:00:00         668  69.634637   66.117558
# 2            2023/01/30         482  19.563271  -41.108627
# 3           09 Feb 2024         284  34.010482  129.946434
# 4            2022-03-09         572  61.148803  115.371931

# %%
patient['birthdate'] = patient['birthdate'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
patient['registration'] = patient['registration'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
patient.head()
# Out:
# C:\Users\mbebe\AppData\Local\Temp\ipykernel_17940\1452451932.py:1: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   patient['birthdate'] = patient['birthdate'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
# C:\Users\mbebe\AppData\Local\Temp\ipykernel_17940\1452451932.py:2: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   patient['registration'] = patient['registration'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
#                                  current_location blood_group  job  \
# 0  (Decimal('-39.6140315'), Decimal('22.351713'))          A+  NaN
# 1    (Decimal('69.634637'), Decimal('66.117558'))         AB-  NaN
# 2   (Decimal('19.563271'), Decimal('-41.108627'))         AB-  NaN
# 3   (Decimal('34.010482'), Decimal('129.946434'))          O-  NaN
# 4   (Decimal('61.148803'), Decimal('115.371931'))          O+  NaN
#
#                           mail  user_id  birthdate               company  \
# 0          schachtkaren@web.de     1135 1923-01-03      Ruppert Stey GbR
# 1             plopes@gmail.com      773 1918-05-23    Gonçalves e Filhos
# 2       tanakayoko@hotmail.com     1532 2001-01-04              中村食品有限会社
# 3        brandoncruz@yahoo.com     2025        NaT         Silva-Gardner
# 4  serragliogiorgio@tiscali.it      638 1997-05-14  Ortese-Agnesi s.r.l.
#
#                      name          username               ssn registration  \
# 0         Raymund Benthin         hornigdan       226-93-4078   2021-04-21
# 1       Leonardo Mendonça     diasana-clara       35096471810   2019-12-16
# 2                   吉田 陽子          sayuri90       066-73-4209   2023-01-30
# 3            Scott Thomas           rossjoy       368-27-2375   2024-02-09
# 4  Dott. Maurilio Zanazzo  orlandogilardoni  SNSGNT39E71B896C   2022-03-09
#
#    station_ID   latitude   longitude
# 0         729 -39.614032   22.351713
# 1         668  69.634637   66.117558
# 2         482  19.563271  -41.108627
# 3         284  34.010482  129.946434
# 4         572  61.148803  115.371931

# %% [markdown]
# We need to verify that no dates were lost in the standarization, at the beginning we had 1170 non-null birthdates and 2128 non-registration and now we have the same number so we didnt lose any information.

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128 entries, 0 to 2127
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   current_location  2022 non-null   object
#  1   blood_group       2128 non-null   object
#  2   job               638 non-null    object
#  3   mail              2128 non-null   object
#  4   user_id           2128 non-null   int64
#  5   birthdate         1170 non-null   datetime64[ns]
#  6   company           2128 non-null   object
#  7   name              2128 non-null   object
#  8   username          2128 non-null   object
#  9   ssn               2128 non-null   object
#  10  registration      2128 non-null   datetime64[ns]
#  11  station_ID        2128 non-null   int64
#  12  latitude          2022 non-null   float64
#  13  longitude         2022 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(8)
# memory usage: 232.9+ KB

# %%
patient.drop(columns=['current_location'], inplace=True)

# %% [markdown]
# Lastly we will reset the user_id.

# %%
patient['user_id'] = range(1, len(patient) + 1)
patient = patient

# %% [markdown]
# <a id="station-3"></a>
# ### Station

# %%
station = station.drop_duplicates()
station[station.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [location, code, revision, station, latitude, longitude]
# Index: []

# %% [markdown]
# We can see there are no duplicate records, but we can also see that there are records that differ by revision only.

# %%
station[station.duplicated(subset=['station', 'latitude', 'longitude'], keep=False)].sort_values(by='station')
# Out:
#                 location code              revision    station  latitude  \
# 245     America/Mazatlan   MX            2019-04-05  Acaponeta  22.49396
# 750     America/Mazatlan   MX           31 Mar 2018  Acaponeta  22.49396
# 691        Europe/Zurich   CH  07/22/2024, 00:00:00   Adliswil  47.30997
# 137        Europe/Zurich   CH            2025-06-25   Adliswil  47.30997
# 159  America/Puerto_Rico   PR            2016/09/10  Aguadilla  18.42745
# ..                   ...  ...                   ...        ...       ...
# 574        Europe/Moscow   RU  03/05/2022, 00:00:00   Zhukovka  53.53395
# 111        Europe/Moscow   RU           26 Jun 2019   Zhukovka  53.53395
# 405        Europe/Moscow   RU            2017/01/14   Zhukovka  53.53395
# 142        Europe/Moscow   RU            2021/06/24   Zhukovka  53.53395
# 520        Europe/Moscow   RU            2017-02-23   Zhukovka  53.53395
#
#      longitude
# 245 -105.36369
# 750 -105.36369
# 691    8.52462
# 137    8.52462
# 159  -67.15407
# ..         ...
# 574   33.72798
# 111   33.72798
# 405   33.72798
# 142   33.72798
# 520   33.72798
#
# [445 rows x 6 columns]

# %% [markdown]
# We have found out before that observation table is linked to station table by latitude and longtitude. We have also observed that there are coordinates in patient table, so we decided to check if they also link the datasets together.

# %%
station_coords = set(zip(station['latitude'], station['longitude']))

patient['matches_station'] = patient.apply(
    lambda row: (row['latitude'], row['longitude']) in station_coords, axis=1
)

num_matches = patient['matches_station'].sum()
total_obs = len(patient)

print(f"{num_matches} out of {total_obs} patient match station coordinates.")
patient.drop(columns=['matches_station'], inplace=True)
# Out:
# 0 out of 2128 patient match station coordinates.

# %%
patient_coords = set(zip(patient['latitude'], patient['longitude']))

station['matches_station'] = station.apply(
    lambda row: (row['latitude'], row['longitude']) in patient_coords, axis=1
)

num_matches = station['matches_station'].sum()
total_obs = len(station)

print(f"{num_matches} out of {total_obs} station match patient coordinates.")
station.drop(columns=['matches_station'], inplace=True)
# Out:
# 0 out of 772 station match patient coordinates.

# %% [markdown]
# We can see that coordinates between patient and station dont match. But we thought that coordinates in patient dataset represent location of homes, which would explain why the coordinates dont match. If this would be true maybe the tables are linked by coordinates in patient table being closest to the coordinates in station table - we can think of this as districts, patient goes to the closest station.
# We have decided to check this by finding each pacients closest station and determining if all patients with this station have same station_ID.

# %%
patient['closest_station_row'] = None

for i, p in patient.iterrows():
    diffs = np.sqrt(
        (station['latitude'] - p['latitude'])**2 +
        (station['longitude'] - p['longitude'])**2
    )
    
    if diffs.notna().any():
        closest_idx = diffs.idxmin()
        patient.at[i, 'closest_station_row'] = closest_idx
    else:
        patient.at[i, 'closest_station_row'] = None

patient.head()
# Out:
#   blood_group  job                         mail  user_id  birthdate  \
# 0          A+  NaN          schachtkaren@web.de        1 1923-01-03
# 1         AB-  NaN             plopes@gmail.com        2 1918-05-23
# 2         AB-  NaN       tanakayoko@hotmail.com        3 2001-01-04
# 3          O-  NaN        brandoncruz@yahoo.com        4        NaT
# 4          O+  NaN  serragliogiorgio@tiscali.it        5 1997-05-14
#
#                 company                    name          username  \
# 0      Ruppert Stey GbR         Raymund Benthin         hornigdan
# 1    Gonçalves e Filhos       Leonardo Mendonça     diasana-clara
# 2              中村食品有限会社                   吉田 陽子          sayuri90
# 3         Silva-Gardner            Scott Thomas           rossjoy
# 4  Ortese-Agnesi s.r.l.  Dott. Maurilio Zanazzo  orlandogilardoni
#
#                 ssn registration  station_ID   latitude   longitude  \
# 0       226-93-4078   2021-04-21         729 -39.614032   22.351713
# 1       35096471810   2019-12-16         668  69.634637   66.117558
# 2       066-73-4209   2023-01-30         482  19.563271  -41.108627
# 3       368-27-2375   2024-02-09         284  34.010482  129.946434
# 4  SNSGNT39E71B896C   2022-03-09         572  61.148803  115.371931
#
#   closest_station_row
# 0                 748
# 1                 630
# 2                 102
# 3                 413
# 4                 470

# %%
patient.sort_values(by='station_ID').head(10)
# Out:
#      blood_group                    job                        mail  user_id  \
# 496          AB-                    NaN          amoreira@gmail.com      497
# 1694          B+                    NaN     pergandeekkehard@aol.de     1695
# 1912         AB-                    NaN  ricolfimelissa@hotmail.com     1913
# 525           B-                    NaN        satotaichi@gmail.com      526
# 1088         AB+                    経営者            yuta59@yahoo.com     1089
# 383           B-                    NaN        nergerali@hotmail.de      384
# 1718          A+                    NaN        mshimizu@hotmail.com     1719
# 1537         AB+                    NaN      brunhildejessel@web.de     1538
# 1121          B+  Child psychotherapist         maria36@hotmail.com     1122
# 1332          A-          Programmierer        tackermann@gmail.com     1333
#
#       birthdate                            company  \
# 496         NaT                              Pires
# 1694 1914-03-28                      Freudenberger
# 1912 1919-04-05  Ajello, Endrizzi e Mercantini SPA
# 525  1914-02-02                           斉藤電気株式会社
# 1088        NaT                           池田建設合同会社
# 383  1969-05-24                       Hermann GmbH
# 1718        NaT                            株式会社森印刷
# 1537 1970-07-11                         Klapp GmbH
# 1121        NaT           Tran, Guerra and Edwards
# 1332 1910-12-07                        Wagenknecht
#
#                                  name         username               ssn  \
# 496                  Nathan Rodrigues      almeidaluna       97251083450
# 1694        Ing. Sigurd Hecker B.Eng.     baererkatrin       104-11-9657
# 1912                   Olga Silvestri        blucchesi  MSTLVR21C10I442X
# 525                             加藤 知実          yuisato       682-99-3294
# 1088                            中村 桃子  takahashisatomi       740-06-7328
# 383       Frau Annelene Scheibe B.Sc.  djacobi-jaeckel       099-77-3510
# 1718                             鈴木 充          kaori56       720-02-5749
# 1537          Kunigunda Hering-Bruder          zenon15       543-10-6498
# 1121                     Daniel Meyer          brian78       372-70-4643
# 1332  Univ.Prof. Valentine Oestrovsky          sstaude       519-68-9808
#
#      registration  station_ID   latitude   longitude closest_station_row
# 496    2023-11-05           0        NaN         NaN                None
# 1694   2022-03-21           1 -62.069471   72.524452                 527
# 1912   2019-07-19           3  74.302313 -133.596072                 251
# 525    2022-11-05           3  38.724572  -20.625429                 540
# 1088   2023-10-19           3 -50.168731   93.008096                  48
# 383    2019-06-01           3 -19.979110   89.268111                 301
# 1718   2024-07-30           4   1.710673   21.537162                 457
# 1537   2024-06-15           4 -48.163785   86.526820                  48
# 1121   2020-05-12           5 -59.065996  120.290969                  48
# 1332   2020-03-21           5 -12.915945  -13.119619                 180

# %% [markdown]
# We can see that patients with same closest station have different station_ID stated.
# This could have been caused by stations being in different countries or despite being closest not being fastest to get to, therefore we decided to visualize all patients stations with x and y being coordinates and their colour being the same for same IDs.

# %%
patient.drop(columns=['closest_station_row'], inplace=True)

# %%
from ipywidgets import interact


unique_stations = patient['station_ID'].unique()
colors = np.random.rand(len(unique_stations), 3)
color_map = {station: color for station, color in zip(unique_stations, colors)}


@interact(station=sorted(unique_stations))
def plot_station(station=3):
    plt.figure(figsize=(10, 8))
    subset = patient[patient['station_ID'] == station]

    plt.scatter(subset['longitude'], subset['latitude'], 
                color=color_map[station], s=50, alpha=0.8)
    
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(f'Patients for Station: {station}')
    plt.grid(True)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='station', index=2, options=(np.int64(0), np.int64(1), np.int64(3),…

# %% [markdown]
# We can chose specific station_ID and watch that the patients with the same station_ID are far away from each other and therefore it is unlikely they refer to the same station. Therefore we concluded that we cannot link the two datasets together and since this column doesnt include any usefull information we will delete it.

# %%
#patient.drop(columns=['station_ID'], inplace=True)

# %% [markdown]
# We did not actually delete this column, becasue we use it for dynamic visualization above.

# %% [markdown]
# For station table we have these problems:
# - revision date doesnt have standarized date type
# - there are duplicites that have everything same but revision date, we have decided to parse this into two tables station and revisions: station table will contain information about stations and revision table will contain information about revisions of the stations, these two tables will be linked by station_identifier, which will be integer specific for each station (this number is different than patient.station_ID), we will also link the station table to observation table with this station_identifier instead of using full set of coordinates.
# - location having continent name and city name, we have decided to parse this into 2 columns: continent and city
# - code has two null values, we will try to fill them in

# %%
station[station['code'].isnull()]
# Out:
#             location code    revision    station  latitude  longitude
# 163  Africa/Windhoek  NaN  2025/07/30  Okahandja -21.98333   16.91667
# 456  Africa/Windhoek  NaN  2022-03-06  Okahandja -21.98333   16.91667

# %% [markdown]
# We can add code to this station, Windhoek is in Namibia which has two letter country code NA.

# %%
station['code'] = station['code'].fillna('NA')
station[station['code'].isnull()]
# Out:
# Empty DataFrame
# Columns: [location, code, revision, station, latitude, longitude]
# Index: []

# %%
station['revision'] = station['revision'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
station.head()
# Out:
# C:\Users\mbebe\AppData\Local\Temp\ipykernel_17940\3436255752.py:1: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   station['revision'] = station['revision'].apply(lambda x: dateparser.parse(str(x)) if pd.notnull(x) else np.nan)
#           location code   revision                   station  latitude  \
# 0    Europe/Madrid   ES 2016-12-22  San Juan de Aznalfarache  37.35813
# 1   America/Bogota   CO 2023-07-22         Villa del Rosario   7.83389
# 2     Asia/Kolkata   IN 2022-09-04                    Rangia  26.44931
# 3  America/Chicago   US 2021-03-29                     Rolla  37.95143
# 4    Europe/Berlin   DE 2023-09-12                  Albstadt  48.21644
#
#    longitude
# 0   -6.03731
# 1  -72.47417
# 2   91.61356
# 3  -91.77127
# 4    9.02596

# %%
station_unique = station[['location', 'code', 'station','latitude','longitude']].drop_duplicates().reset_index(drop=True)
station_unique['station_id'] = range(0, len(station_unique))
revision = station.merge(station_unique,on=['location', 'code', 'station','latitude','longitude'],how='right') 
revision.drop(columns=['location', 'code', 'station','latitude','longitude'], inplace=True)
revision = revision[['station_id','revision']]
station = station_unique[['station_id', 'location', 'code', 'station','latitude','longitude']]

# %%
station.head()
# Out:
#    station_id         location code                   station  latitude  \
# 0           0    Europe/Madrid   ES  San Juan de Aznalfarache  37.35813
# 1           1   America/Bogota   CO         Villa del Rosario   7.83389
# 2           2     Asia/Kolkata   IN                    Rangia  26.44931
# 3           3  America/Chicago   US                     Rolla  37.95143
# 4           4    Europe/Berlin   DE                  Albstadt  48.21644
#
#    longitude
# 0   -6.03731
# 1  -72.47417
# 2   91.61356
# 3  -91.77127
# 4    9.02596

# %%
revision.head().sort_values(by='station_id')
revision['station_id'] = revision['station_id'].astype(int)

# %%
temp = revision.merge(station,on=['station_id'],how='left')
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   station_id  772 non-null    int64
#  1   revision    772 non-null    datetime64[ns]
#  2   location    772 non-null    object
#  3   code        772 non-null    object
#  4   station     772 non-null    object
#  5   latitude    772 non-null    float64
#  6   longitude   772 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 42.3+ KB

# %% [markdown]
# We can see that after the parsing of tables and then merging them back together we still have 772 records with 2 codes being null.

# %% [markdown]
# Next we replace the coordinates with newly created station_id

# %%
observation = observation.merge(station, on=['latitude','longitude'],how='left')
observation.drop(columns=['location', 'code', 'station','latitude','longitude'], inplace=True)
observation['station_id'] = observation['station_id'].astype(int)
observation.head()
# Out:
#         SpO₂         HR         PI         RR      EtCO₂       FiO₂  \
# 0  96.511604  67.597663  14.451123  17.461063  41.262037  87.821291
# 1  98.113516  72.872900   4.699563  17.231104  40.220086  64.283914
# 2  98.623248  81.418306  12.056504  16.832868  39.953184  77.164206
# 3  96.821905  69.356881  11.044410  14.876013  38.765113  59.296747
# 4  98.523262  70.686313   5.963887  16.933547  41.470854  66.145767
#
#           PRV          BP  Skin Temperature  Motion/Activity index  ...  \
# 0  126.965235  109.471152         35.650826              11.429092  ...
# 1  139.509502  100.943658         35.313317              11.188645  ...
# 2  104.396821  107.401302         36.017931               8.980842  ...
# 3  180.845101  106.786082         35.433515               9.952747  ...
# 4  111.525074  108.354216         35.258355              10.619401  ...
#
#           SV        CO  Blood Flow Index  PPG waveform features  \
# 0  83.801243  4.004591         44.065731              36.604550
# 1  78.047479  4.014983         36.498878              61.305805
# 2  86.640923  4.083922         52.803185              49.432273
# 3  87.187544  4.006763         52.800923              68.710875
# 4  87.354000  4.008813         25.406073              33.993656
#
#    Signal Quality Index  Respiratory effort  O₂ extraction ratio        SNR  \
# 0             69.140438           57.097309             0.210117  33.584512
# 1             50.733704           61.220158             0.293664  30.528645
# 2             41.841466           57.554854             0.232518  22.357337
# 3             47.524447           48.971775             0.288125  25.886190
# 4             60.323832           54.807359             0.295855  20.836752
#
#    oximetry  station_id
# 0      True         461
# 1      True         166
# 2      True          34
# 3     False          66
# 4      True         266
#
# [5 rows x 22 columns]

# %% [markdown]
# Lastly we will parse the location into continent and city column.

# %%
station = station.copy()
station[['continent', 'city']] = station['location'].str.split('/', n=1, expand=True)
station['station_id'] = station['station_id'].astype(int)
station.drop(columns=['location'], inplace=True)
station.head()
station = station[['station_id','station','code','continent','city','latitude','longitude']]
patient = patient[['user_id','mail','username','name','ssn','blood_group','job','company','birthdate','latitude','longitude','registration','station_ID']]

# %% [markdown]
# ---
# <br><br><br>

# %% [markdown]
# <a id="data-accuracy-check"></a>
# ## B -  Data accuracy check

# %% [markdown]
# Do the data contain abnormal values?
# Do they include illogical relationships caused by data collection or annotation errors?

# %% [markdown]
# <br><br>
# Illogical problems with data and abnormal values:

# %% [markdown]
# Observation
# - for this dataset the coordination was used to identify station, this can be replaced by using user_id
#
# Patient
# - for patient we had one extra column that wasnt needed
# - we had column with coordinates as text, which wasnt consistent with other coordinates
# - mail and username should be unique for each person
# - user_id wasnt unique for each person, we have fixed this
# - dates had unstandarized formating
# - station_ID had no purpose since it didnt link patient to any station
#
# Station
# - dates had unstandarized formating
# - location was in one column which contained both continent and city, this isnt suitable when getting the data
# - table was not normalized - we have parsed it into two tables
# - stations didnt have station_id as unique identifier of each station
#
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="outlier-detection"></a>
# ## C - Outlier detection

# %% [markdown]
# Try to solve the problem using at least two techniques, e.g.:
#  - Removing outliers or extreme observations
#  - Replacing outliers with boundary values of the distribution (e.g., 5%, 95%)

# %%
numeric_cols = observation.select_dtypes(include=["float64", "int64"]) #vpodstate vse
rows, cols = 5, 5
fig, axes = plt.subplots(rows, cols, figsize=(20, 20))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    numeric_cols.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col, fontsize=12)
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.suptitle("Boxplots of Attributes", fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# We have displayed boxplot showing us outlier os every parameter inside of observation dataset.
# This diagram was already shown before in the section 1.1.C, but we show it here once again to provide quick look at the outliers.

# %%
normal_vars = [
    'HR', 'FiO₂', 'PRV', 'Skin Temperature', 'Motion/Activity index',
    'Hb level', 'Blood Flow Index', 'PPG waveform features',
    'Signal Quality Index', 'Respiratory effort'
]

outlier_counts_std = {}
for col in normal_vars:
    data = observation[col].dropna()
    mean_val, std_val = data.mean(), data.std()
    lower, upper = mean_val - 3 * std_val, mean_val + 3 * std_val
    outliers = data[(data < lower) | (data > upper)]
    outlier_counts_std[col] = len(outliers)

outlier_df_std = pd.DataFrame.from_dict(outlier_counts_std, orient='index', columns=['Outliers'])
outlier_df_std = outlier_df_std.sort_values('Outliers', ascending=False)

total_outliers_std = outlier_df_std['Outliers'].sum()
print(f"Total number of potential outliers (3σ rule, normal variables only): {total_outliers_std}")

plt.figure(figsize=(12, 6))
sns.barplot(x=outlier_df_std.index, y=outlier_df_std['Outliers'])
plt.xticks(rotation=45, ha='right')
plt.title('Outlier Count by Attribute (3σ Rule - Normal Variables)')
plt.ylabel('Number of Outliers')
plt.xlabel('Attribute')
plt.tight_layout()
plt.show()

display(outlier_df_std)
# Out:
# Total number of potential outliers (3σ rule, normal variables only): 297
#                        Outliers
# Skin Temperature             36
# Hb level                     34
# Motion/Activity index        32
# Blood Flow Index             32
# Signal Quality Index         29
# HR                           29
# FiO₂                         28
# PPG waveform features        28
# Respiratory effort           27
# PRV                          22

# %% [markdown]
# Here we used the 3σ rule to find data points that are more than three standard deviations away from the mean. This helps spot values that are unusually high or low compared to the rest. We found 297 potential outliers. Yet the number would b ehigher but we had to isolate part of the dataset which contained values that didnt follow normal distribution, so for this method we used only those who do follow it, those are: HR, FiO₂, PRV, Skin Temperature, Motion/Activity index, Hb level, Blood Flow Index, PPG waveform features, Signal Quality Index, Respiratory effort. From the graph and table above it, we can determine that the values with most outliers are: Skin Temperature, Hb level, Motion/Activity index and Blood Flow Index.

# %%
top_std_cols = outlier_df_std.head(4).index

for col in top_std_cols:
    data = observation[col].dropna()
    mean_val, std_val = data.mean(), data.std()
    lower, upper = mean_val - 3 * std_val, mean_val + 3 * std_val

    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data, color='skyblue')
    plt.axvline(lower, color='red', linestyle='--', label='Lower bound (3σ)')
    plt.axvline(upper, color='red', linestyle='--', label='Upper bound (3σ)')
    plt.title(f'{col} – 3σ Outlier Boundaries')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Here we have used boxplots to visualize attributes with the most outliers. The plots for Skin Temperature, Hb level, Motion/Activity index and Blood Flow Index confirmed that these parameters have some extreme values, showing strong variability or possible measurement issues. This step helped us confirm the statistical results visually.

# %%
outlier_counts_iqr = {}

for col in numeric_cols:
    data = observation[col].dropna()
    q25, q75 = np.percentile(data, [25, 75])
    iqr = q75 - q25
    lower, upper = q25 - 1.5 * iqr, q75 + 1.5 * iqr
    
    outliers = data[(data < lower) | (data > upper)]
    outlier_counts_iqr[col] = len(outliers)

outlier_df_iqr = pd.DataFrame.from_dict(outlier_counts_iqr, orient='index', columns=['Outliers'])
outlier_df_iqr = outlier_df_iqr.sort_values('Outliers', ascending=False)

total_outliers_iqr = outlier_df_iqr['Outliers'].sum()

print(f" Total number of potential outliers (IQR method): {total_outliers_iqr}")

plt.figure(figsize=(12,6))
sns.barplot(x=outlier_df_iqr.index, y=outlier_df_iqr['Outliers'])
plt.xticks(rotation=45, ha='right')
plt.title('Outlier Count by Attribute (IQR Method)')
plt.ylabel('Number of Outliers')
plt.xlabel('Attribute')
plt.tight_layout()
plt.show()

display(outlier_df_iqr)
# Out:
#  Total number of potential outliers (IQR method): 2188
#                        Outliers
# CO                          967
# BP                          142
# PVI                         137
# Skin Temperature            101
# Hb level                     98
# Respiratory effort           94
# Signal Quality Index         91
# SV                           83
# PPG waveform features        82
# HR                           82
# Blood Flow Index             81
# FiO₂                         80
# Motion/Activity index        78
# PRV                          61
# EtCO₂                         6
# RR                            3
# SpO₂                          2
# PI                            0
# O₂ extraction ratio           0
# SNR                           0
# station_id                    0

# %% [markdown]
# The IQR method was used next because it works better for data that isn’t perfectly normal. It looks for values that are too far from the middle 50% of the data. This method found 2,188 outliers, again mostly in CO, BP, and PVI, but also in Skin Temperature and Hb level. The higher count means the IQR method is more sensitive to extreme values.

# %%
top_iqr_cols = outlier_df_iqr.head(4).index

for col in top_iqr_cols:
    data = observation[col].dropna()
    q25, q75 = np.percentile(data, [25, 75])
    iqr = q75 - q25
    lower, upper = q25 - 1.5 * iqr, q75 + 1.5 * iqr

    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data) 
    plt.axvline(lower, color='orange', linestyle='--', label='Lower bound (IQR)')
    plt.axvline(upper, color='orange', linestyle='--', label='Upper bound (IQR)')
    plt.title(f'{col} – IQR Outlier Boundaries')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Finally, we plotted boxplots for the variables with the most outliers based on the IQR rule. They clearly show that CO, BP, and PVI have a lot of data points outside the normal range. This confirms what we saw earlier — these attributes show big differences between patients or possible sensor noise.

# %% [markdown]
# To summarize, we used two different statistical methods — the 3σ rule and the IQR method — to identify potential outliers in the dataset.
# We visualized the results using boxplots, which helped highlight variables such as CO, BP, and PVI, where extreme values were most common.
# Both methods detected several potential outliers, after comparing the results with the acceptable measurement ranges, we concluded that all detected values still fall within realistic physiological limits.
# Therefore, no data points were removed or replaced, as these values likely represent valid but rare observations rather than measurement errors.

# %%
top_iqr_cols = ['CO', 'BP', 'PVI', 'Skin Temperature', 'Hb level']  # You can adjust top 5 or more

plt.figure(figsize=(10, 20))
sns.boxplot(data=observation[top_iqr_cols], palette='Set2')
plt.title('Boxplot Before Capping Outliers (IQR Method)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
observation.nunique()
# Out:
# SpO₂                     11928
# HR                       11928
# PI                       11928
# RR                       11928
# EtCO₂                    11928
# FiO₂                     11928
# PRV                      11928
# BP                       11928
# Skin Temperature         11928
# Motion/Activity index    11928
# PVI                      11928
# Hb level                 11928
# SV                       11928
# CO                       11928
# Blood Flow Index         11928
# PPG waveform features    11928
# Signal Quality Index     11928
# Respiratory effort       11928
# O₂ extraction ratio      11928
# SNR                      11928
# oximetry                     2
# station_id                 519
# dtype: int64

# %%
total_capped = 0
capped_summary = []

exclude_cols = ['station_id']  

for col in numeric_cols:
    if col in exclude_cols:
        capped_summary.append([col, 0, 0, 0])
        continue

    data = observation[col].dropna()
    lower_bound = np.percentile(data, 5)
    upper_bound = np.percentile(data, 95)

    below = (observation[col] < lower_bound).sum()
    above = (observation[col] > upper_bound).sum()
    capped = below + above

    observation[col] = np.where(observation[col] < lower_bound, lower_bound, observation[col])
    observation[col] = np.where(observation[col] > upper_bound, upper_bound, observation[col])

    capped_summary.append([col, below, above, capped])
    total_capped += capped

capped_df = pd.DataFrame(capped_summary, columns=['Variable', 'Capped Below 5%', 'Capped Above 95%', 'Total Capped'])
capped_df = capped_df.sort_values('Total Capped', ascending=False)

print(f"Total number of capped values across all numeric columns (excluding station_id): {total_capped}")
display(capped_df)
# Out:
# Total number of capped values across all numeric columns (excluding station_id): 24240
#                  Variable  Capped Below 5%  Capped Above 95%  Total Capped
# 0                    SpO₂              606               606          1212
# 1                      HR              606               606          1212
# 2                      PI              606               606          1212
# 3                      RR              606               606          1212
# 4                   EtCO₂              606               606          1212
# 5                    FiO₂              606               606          1212
# 6                     PRV              606               606          1212
# 7                      BP              606               606          1212
# 8        Skin Temperature              606               606          1212
# 9   Motion/Activity index              606               606          1212
# 10                    PVI              606               606          1212
# 11               Hb level              606               606          1212
# 12                     SV              606               606          1212
# 13                     CO              606               606          1212
# 14       Blood Flow Index              606               606          1212
# 15  PPG waveform features              606               606          1212
# 16   Signal Quality Index              606               606          1212
# 17     Respiratory effort              606               606          1212
# 18    O₂ extraction ratio              606               606          1212
# 19                    SNR              606               606          1212
# 20             station_id                0                 0             0

# %%
plt.figure(figsize=(10, 20))
sns.boxplot(data=observation[top_iqr_cols], palette='Set2')
plt.title('Boxplot After Capping Outliers (5th and 95th Percentiles)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Here we first identify the top variables with the most outliers based on the IQR method.
#  We visualize their distributions using boxplots to see extreme values (outliers) clearly.
#
# Next, we cap the outliers by replacing values below the 5th percentile with the 5th percentile
# and values above the 95th percentile with the 95th percentile. This reduces the influence of extreme values on analyses or models while preserving the overall distribution of the data.
#
# Finally, we plot the boxplots again to visualize the effect: after capping, extreme outliers are limited to the boundary values, leading to more stable distributions and preventing them from skewing statistical analyses or plots.
#
# ---
#
# <br><br><br>

# %% [markdown]
# <a id="13---formulation-and-statistical-verification-of-hypotheses-about-the-data"></a>
# ## 1.3 Formulation and statistical verification of hypotheses about the data

# %% [markdown]
# Formulate two hypotheses about the data in the context of the given prediction task. Verify the formulated hypotheses using appropriately chosen statistical tests.
# Example formulation:
# “FiO₂ has a higher average value in the state with oximetry than without it.”

# %% [markdown]
# <a id="hypothesis-1"></a>
# ### Hypothesis 1

# %% [markdown]
# We have a hypothesis that group of people with oximetry have higher RR (Respiratory rate).
#
# <br>
#
# **$H_0$ (null hypothesis)**: The Respiratory rate of people with oximetry is **the same** on average as the respiratory rate of people without oximetry.
#
# **$H_1 = H_A$ (alternative hypothesis)**: The Respiratory rate of people with oximetry is **different** on average as the respiratory rate of people without oximetry.

# %% [markdown]
# The groups of observations are independent since one observation can be with oximetry or without oximetry.

# %%
with_oximetry = observation.loc[observation.oximetry == True, 'RR']
without_oximetry = observation.loc[observation.oximetry == False, 'RR']
print('oximetry')
print(len(with_oximetry))
print('no oximetry')
print(len(without_oximetry))
# Out:
# oximetry
# 7225
# no oximetry
# 4881

# %% [markdown]
# We can see that each group has more then 20 elements. Next we will confirm that we have no outliers in each group.

# %%
from scipy.stats import iqr

def identify_outliers(a):
    lower = a.quantile(0.25) - 1.5 * iqr(a)
    upper = a.quantile(0.75) + 1.5 * iqr(a)
    
    return a[(a > upper) | (a < lower)]



outliers = identify_outliers(with_oximetry)
while not outliers.empty:
    with_oximetry = with_oximetry.drop(outliers.index)
    outliers = identify_outliers(with_oximetry)

outliers = identify_outliers(without_oximetry)
while not outliers.empty:
    without_oximetry = without_oximetry.drop(outliers.index)
    outliers = identify_outliers(without_oximetry)

# %%
sns.boxplot(with_oximetry)
# Out:
# <Axes: ylabel='RR'>

# %%
sns.boxplot(without_oximetry)
# Out:
# <Axes: ylabel='RR'>

# %% [markdown]
# We can see there are no outliers. Next we check for normality.

# %%
fig, axes = plt.subplots(1, 2, figsize=(40, 20))

sns.kdeplot(with_oximetry, ax=axes[0], fill=True, alpha=0.3)
axes[0].set_title('with_oximetry')
axes[0].legend(['with_oximetry'])

sns.kdeplot(without_oximetry, ax=axes[1], fill=True, alpha=0.3)
axes[1].set_title('without_oximetry')
axes[1].legend(['without_oximetry'])


plt.tight_layout()
plt.show()

# %%
print("with_oximetry:", normaltest(with_oximetry))
print("without_oximetry:", normaltest(without_oximetry))
# Out:
# with_oximetry: NormaltestResult(statistic=np.float64(472.0130062216216), pvalue=np.float64(3.1891724643418876e-103))
# without_oximetry: NormaltestResult(statistic=np.float64(211.6456015273203), pvalue=np.float64(1.100884022723109e-46))

# %% [markdown]
# We can see that the groups are not normally distributed. Therefore we will use Mann-Whiteney U-test test.

# %%
mannwhitneyu(with_oximetry,without_oximetry)
# Out:
# MannwhitneyuResult(statistic=np.float64(31326056.0), pvalue=np.float64(0.0))

# %% [markdown]
# p-value is smaller then 0.05 therefore we reject **$H_0$ (null hypothesis)** and we can say that there is a statisticall difference Respiratory rate between groups with oximetry and without oximetry.

# %%
sns.barplot(x='oximetry', y='RR', data=observation, capsize=0.1, err_kws={'linewidth': 2})
# Out:
# <Axes: xlabel='oximetry', ylabel='RR'>

# %% [markdown]
# We can also see that when oximetry is false, the respiratory rate is noticeably lower.

# %% [markdown]
# <a id="statistical-power-1"></a>
# #### Statistical power

# %% [markdown]
# Verify whether your statistical tests have sufficient support from the data — that is, whether they have enough statistical power.
#
# <br>

# %% [markdown]
# We have this way of calculating statistical power, using Cohens d:

# %% [markdown]
# $d = \frac{\overline{x_1} - \overline{x_2}}{s}$
#
#
#  $s = \sqrt{\frac{(n_1 - 1) s^2_{X_1} + (n_2 - 1) s^2_{X_2}}{n_1 + n_2 - 2}}$

# %%
def cohens_d(x1, x2):
    nx1 = len(x1)
    nx2 = len(x2)
    s = np.sqrt(((nx1-1) * np.std(x1, ddof=1)**2 + (nx2-1) * np.std(x2, ddof=1)**2) / (nx1 + nx2 - 2))
    return (np.abs(np.mean(x1) - np.mean(x2))) / s




c_d = cohens_d(with_oximetry, without_oximetry)
print(c_d)
# Out:
# 2.0736309371246144

# %% [markdown]
# We can see that the test has very large effect.

# %%
sm_stats.power.tt_ind_solve_power(c_d, len(with_oximetry), 0.05, None, len(without_oximetry)/len(with_oximetry))
# Out:
# np.float64(1.0)

# %% [markdown]
# Statistical power for this test is 1.

# %% [markdown]
# <a id="hypothesis-2"></a>
# ### Hypothesis 2

# %% [markdown]
# We have a hypothesis that group of people with oximetry have higher SpO₂.
#
# <br>
#
# **$H_0$ (null hypothesis)**: The value of SpO₂ of people with oximetry is **the same** on average as the respiratory rate of people without oximetry.
#
# **$H_1 = H_A$ (alternative hypothesis)**: The value of SpO₂ of people with oximetry is **different** on average as the respiratory rate of people without oximetry.

# %%
SPO2_with_oximetry = observation.loc[observation.oximetry == True, 'SpO₂']
SPO2_without_oximetry = observation.loc[observation.oximetry == False, 'SpO₂']
print('oximetry')
print(len(SPO2_with_oximetry))
print('no oximetry')
print(len(SPO2_without_oximetry))
# Out:
# oximetry
# 7225
# no oximetry
# 4881

# %%
sns.boxplot(SPO2_with_oximetry)
# Out:
# <Axes: ylabel='SpO₂'>

# %%
sns.boxplot(without_oximetry)
# Out:
# <Axes: ylabel='RR'>

# %% [markdown]
# Here we displayed that the 2 groups, with and without oximetry do not have any outliers, now we can fosuc on atribus sucha s normality of these 2 groups.

# %%
fig, axes = plt.subplots(1, 2, figsize=(40, 20))

sns.kdeplot(SPO2_with_oximetry, ax=axes[0], fill=True, alpha=0.3)
axes[0].set_title('SPO2_with_oximetry')
axes[0].legend(['SPO2_with_oximetry'])

sns.kdeplot(SPO2_without_oximetry, ax=axes[1], fill=True, alpha=0.3)
axes[1].set_title('SpO₂without_oximetry')
axes[1].legend(['SPO2_without_oximetry'])


plt.tight_layout()
plt.show()

# %%
print("SPO2_with_oximetry:", normaltest(SPO2_with_oximetry))
print("SPO2_without_oximetry:", normaltest(SPO2_without_oximetry))
# Out:
# SPO2_with_oximetry: NormaltestResult(statistic=np.float64(705.782994252423), pvalue=np.float64(5.5102345750970206e-154))
# SPO2_without_oximetry: NormaltestResult(statistic=np.float64(323.97178835426337), pvalue=np.float64(4.4711579551442185e-71))

# %% [markdown]
# We can see that the groups are not normally distributed. Therefore we will use Mann-Whiteney U-test test.

# %%
mannwhitneyu(SPO2_with_oximetry,SPO2_without_oximetry)
# Out:
# MannwhitneyuResult(statistic=np.float64(25940431.0), pvalue=np.float64(0.0))

# %% [markdown]
# p-value is smaller then 0.05 therefore we reject **$H_0$ (null hypothesis)** and we can say that there is a statisticall difference SpO₂ between groups with oximetry and without oximetry.

# %%
sns.barplot(x='oximetry', y='SpO₂', data=observation, capsize=0.1, err_kws={'linewidth': 2})
plt.ylim(97, 100)
plt.title('SpO₂ vs Oximetry (90–100)')
plt.tight_layout()
plt.show()

# %% [markdown]
# We can also see the diffrance on the folowing picture.

# %% [markdown]
# <a id="statistical-power-2"></a>
# #### Statistical power

# %% [markdown]
# Verify whether your statistical tests have sufficient support from the data — that is, whether they have enough statistical power.

# %% [markdown]
# We have this way of calculating statistical power, using Cohens d:

# %% [markdown]
# $d = \frac{\overline{x_1} - \overline{x_2}}{s}$
#
#
#  $s = \sqrt{\frac{(n_1 - 1) s^2_{X_1} + (n_2 - 1) s^2_{X_2}}{n_1 + n_2 - 2}}$

# %%
c_d_2 = cohens_d(SPO2_with_oximetry, SPO2_without_oximetry)
print(c_d_2)
# Out:
# 0.8011698155518087

# %% [markdown]
# We can see that the test has very large effect (large effect = 0.8).

# %%
sm_stats.power.tt_ind_solve_power(c_d_2, len(SPO2_with_oximetry), 0.05, None, len(SPO2_without_oximetry)/len(SPO2_with_oximetry))
# Out:
# np.float64(1.0)

# %% [markdown]
# Statistical power for this test is 1.

# %% [markdown]
# <a id="conclusion"></a>
# # Conclusion

# %% [markdown]
# In the following part of our project, we have successfully prepared the data required for the model that we will train using this newly processed dataset. Throughout this stage, we gained a deeper understanding of the relationships between the values within the various datasets, allowing us to identify important patterns and ensure data consistency. This knowledge will be essential as we move forward to the next phases of our team project, where we will apply these insights to improve model accuracy and overall project outcomes.

# %%
observation.to_csv("dataset/new_observation.csv")
station.to_csv("dataset/new_station.csv")
patient.to_csv("dataset/new_patient.csv")
revision.to_csv("dataset/new_revision.csv")
